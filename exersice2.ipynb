# %% [markdown]
# # Good Sayer

# %%
name = input("Enter Your Name :- ")

# %%
import time
timnow =time.localtime(time.time()).tm_hour
if(timenow >= 5 and timenow < 12) :
    print(f"Good Morning {name}")
    print(f"Make Tea ☕ For Both Of Us")
elif(timenow >= 12 and timenow < 18) :
    print(f"Good Evening {name}")
    print(f"Take Rest 😩 From Work")
elif(timenow >= 18 or timenow < 5) :
    print(f"Good Night {name}")
    print(f"Just Sleep For A new Fresh Day Fast ")
# Out:
# Good Evening Abhi
# Take Rest 😩 From Work
